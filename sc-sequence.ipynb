# %%
# %pip install scanpy
# %pip install anndata   
# %pip install pooch    
# %pip install igraph
# Out:
# Requirement already satisfied: scanpy in /opt/anaconda3/lib/python3.11/site-packages (1.11.5)
# Requirement already satisfied: anndata>=0.8 in /opt/anaconda3/lib/python3.11/site-packages (from scanpy) (0.12.10)
# Requirement already satisfied: h5py>=3.7.0 in /opt/anaconda3/lib/python3.11/site-packages (from scanpy) (3.9.0)
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.11/site-packages (from scanpy) (1.5.3)
# Requirement already satisfied: legacy-api-wrap>=1.4.1 in /opt/anaconda3/lib/python3.11/site-packages (from scanpy) (1.5)
# Requirement already satisfied: matplotlib>=3.7.5 in /opt/anaconda3/lib/python3.11/site-packages (from scanpy) (3.8.0)
# Requirement already satisfied: natsort in /opt/anaconda3/lib/python3.11/site-packages (from scanpy) (8.4.0)
# Requirement already satisfied: networkx>=2.7.1 in /opt/anaconda3/lib/python3.11/site-packages (from scanpy) (3.1)
# Requirement already satisfied: numba!=0.62.0rc1,>=0.57.1 in /opt/anaconda3/lib/python3.11/site-packages (from scanpy) (0.59.0)
# Requirement already satisfied: numpy>=1.24.1 in /opt/anaconda3/lib/python3.11/site-packages (from scanpy) (1.26.4)
# Requirement already satisfied: packaging>=21.3 in /opt/anaconda3/lib/python3.11/site-packages (from scanpy) (26.0)
# Requirement already satisfied: pandas>=1.5.3 in /opt/anaconda3/lib/python3.11/site-packages (from scanpy) (2.1.4)
# Requirement already satisfied: patsy!=1.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from scanpy) (1.0.2)
# Requirement already satisfied: pynndescent>=0.5.13 in /opt/anaconda3/lib/python3.11/site-packages (from scanpy) (0.6.0)
# Requirement already satisfied: scikit-learn>=1.1.3 in /opt/anaconda3/lib/python3.11/site-packages (from scanpy) (1.8.0)
# Requirement already satisfied: scipy>=1.8.1 in /opt/anaconda3/lib/python3.11/site-packages (from scanpy) (1.16.3)
# Requirement already satisfied: seaborn>=0.13.2 in /opt/anaconda3/lib/python3.11/site-packages (from scanpy) (0.13.2)
# Requirement already satisfied: session-info2 in /opt/anaconda3/lib/python3.11/site-packages (from scanpy) (0.4)
# Requirement already satisfied: statsmodels>=0.14.5 in /opt/anaconda3/lib/python3.11/site-packages (from scanpy) (0.14.6)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.11/site-packages (from scanpy) (4.65.0)
# Requirement already satisfied: typing-extensions in /opt/anaconda3/lib/python3.11/site-packages (from scanpy) (4.15.0)
# Requirement already satisfied: umap-learn>=0.5.6 in /opt/anaconda3/lib/python3.11/site-packages (from scanpy) (0.5.11)
# Requirement already satisfied: array-api-compat>=1.7.1 in /opt/anaconda3/lib/python3.11/site-packages (from anndata>=0.8->scanpy) (1.13.0)
# Requirement already satisfied: zarr!=3.0.*,>=2.18.7 in /opt/anaconda3/lib/python3.11/site-packages (from anndata>=0.8->scanpy) (3.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.7.5->scanpy) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.7.5->scanpy) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.7.5->scanpy) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.7.5->scanpy) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.7.5->scanpy) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.7.5->scanpy) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.7.5->scanpy) (2.8.2)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in /opt/anaconda3/lib/python3.11/site-packages (from numba!=0.62.0rc1,>=0.57.1->scanpy) (0.42.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas>=1.5.3->scanpy) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas>=1.5.3->scanpy) (2023.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-learn>=1.1.3->scanpy) (3.6.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.7.5->scanpy) (1.16.0)
# Requirement already satisfied: donfig>=0.8 in /opt/anaconda3/lib/python3.11/site-packages (from zarr!=3.0.*,>=2.18.7->anndata>=0.8->scanpy) (0.8.1.post1)
# Requirement already satisfied: google-crc32c>=1.5 in /opt/anaconda3/lib/python3.11/site-packages (from zarr!=3.0.*,>=2.18.7->anndata>=0.8->scanpy) (1.8.0)
# Requirement already satisfied: numcodecs>=0.14 in /opt/anaconda3/lib/python3.11/site-packages (from zarr!=3.0.*,>=2.18.7->anndata>=0.8->scanpy) (0.16.5)
# Requirement already satisfied: pyyaml in /opt/anaconda3/lib/python3.11/site-packages (from donfig>=0.8->zarr!=3.0.*,>=2.18.7->anndata>=0.8->scanpy) (6.0.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: anndata in /opt/anaconda3/lib/python3.11/site-packages (0.12.10)
# Requirement already satisfied: array-api-compat>=1.7.1 in /opt/anaconda3/lib/python3.11/site-packages (from anndata) (1.13.0)
# Requirement already satisfied: h5py>=3.8 in /opt/anaconda3/lib/python3.11/site-packages (from anndata) (3.9.0)
# Requirement already satisfied: legacy-api-wrap in /opt/anaconda3/lib/python3.11/site-packages (from anndata) (1.5)
# Requirement already satisfied: natsort in /opt/anaconda3/lib/python3.11/site-packages (from anndata) (8.4.0)
# Requirement already satisfied: numpy>=1.26 in /opt/anaconda3/lib/python3.11/site-packages (from anndata) (1.26.4)
# Requirement already satisfied: packaging>=24.2 in /opt/anaconda3/lib/python3.11/site-packages (from anndata) (26.0)
# Requirement already satisfied: pandas!=2.1.2,<3,>=2.1.0 in /opt/anaconda3/lib/python3.11/site-packages (from anndata) (2.1.4)
# Requirement already satisfied: scipy!=1.17.0,>=1.12 in /opt/anaconda3/lib/python3.11/site-packages (from anndata) (1.16.3)
# Requirement already satisfied: zarr!=3.0.*,>=2.18.7 in /opt/anaconda3/lib/python3.11/site-packages (from anndata) (3.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.11/site-packages (from pandas!=2.1.2,<3,>=2.1.0->anndata) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas!=2.1.2,<3,>=2.1.0->anndata) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas!=2.1.2,<3,>=2.1.0->anndata) (2023.3)
# Requirement already satisfied: donfig>=0.8 in /opt/anaconda3/lib/python3.11/site-packages (from zarr!=3.0.*,>=2.18.7->anndata) (0.8.1.post1)
# Requirement already satisfied: google-crc32c>=1.5 in /opt/anaconda3/lib/python3.11/site-packages (from zarr!=3.0.*,>=2.18.7->anndata) (1.8.0)
# Requirement already satisfied: numcodecs>=0.14 in /opt/anaconda3/lib/python3.11/site-packages (from zarr!=3.0.*,>=2.18.7->anndata) (0.16.5)
# Requirement already satisfied: typing-extensions>=4.9 in /opt/anaconda3/lib/python3.11/site-packages (from zarr!=3.0.*,>=2.18.7->anndata) (4.15.0)
# Requirement already satisfied: pyyaml in /opt/anaconda3/lib/python3.11/site-packages (from donfig>=0.8->zarr!=3.0.*,>=2.18.7->anndata) (6.0.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas!=2.1.2,<3,>=2.1.0->anndata) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pooch in /opt/anaconda3/lib/python3.11/site-packages (1.9.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /opt/anaconda3/lib/python3.11/site-packages (from pooch) (3.10.0)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.11/site-packages (from pooch) (26.0)
# Requirement already satisfied: requests>=2.19.0 in /opt/anaconda3/lib/python3.11/site-packages (from pooch) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->pooch) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->pooch) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->pooch) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->pooch) (2026.1.4)
# Note: you may need to restart the kernel to use updated packages.
# Collecting igraph
#   Downloading igraph-1.0.0-cp39-abi3-macosx_11_0_arm64.whl.metadata (4.4 kB)
# Collecting texttable>=1.6.2 (from igraph)
#   Downloading texttable-1.7.0-py2.py3-none-any.whl.metadata (9.8 kB)
# Downloading igraph-1.0.0-cp39-abi3-macosx_11_0_arm64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 10.9 MB/s eta 0:00:00a 0:00:01
# Downloading texttable-1.7.0-py2.py3-none-any.whl (10 kB)
# Installing collected packages: texttable, igraph
# Successfully installed igraph-1.0.0 texttable-1.7.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# Core scverse libraries
from __future__ import annotations
# Data retrieval
import pooch
import scanpy as sc
import anndata as ad

# %%
sc.settings.set_figure_params(dpi=50, facecolor="white")

# %%
EXAMPLE_DATA = pooch.create(
    path=pooch.os_cache("scverse_tutorials"),
    base_url="doi:10.6084/m9.figshare.22716739.v1/",
)
EXAMPLE_DATA.load_registry_from_doi()

# %%
samples = {
    "s1d1": "s1d1_filtered_feature_bc_matrix.h5",
    "s1d3": "s1d3_filtered_feature_bc_matrix.h5",
}
adatas = {}

for sample_id, filename in samples.items():
    path = EXAMPLE_DATA.fetch(filename)
    sample_adata = sc.read_10x_h5(path)
    sample_adata.var_names_make_unique()
    adatas[sample_id] = sample_adata

adata = ad.concat(adatas, label="sample")
adata.obs_names_make_unique()
print(adata.obs["sample"].value_counts())
adata
# Out:
# Downloading file 's1d1_filtered_feature_bc_matrix.h5' from 'doi:10.6084/m9.figshare.22716739.v1/s1d1_filtered_feature_bc_matrix.h5' to '/Users/shanshanxu/Library/Caches/scverse_tutorials'.
# /opt/anaconda3/lib/python3.11/site-packages/anndata/_core/anndata.py:1825: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /opt/anaconda3/lib/python3.11/site-packages/anndata/_core/anndata.py:1825: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# Downloading file 's1d3_filtered_feature_bc_matrix.h5' from 'doi:10.6084/m9.figshare.22716739.v1/s1d3_filtered_feature_bc_matrix.h5' to '/Users/shanshanxu/Library/Caches/scverse_tutorials'.
# sample
# s1d1    8785
# s1d3    8340
# Name: count, dtype: int64
# /opt/anaconda3/lib/python3.11/site-packages/anndata/_core/anndata.py:1825: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /opt/anaconda3/lib/python3.11/site-packages/anndata/_core/anndata.py:1825: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /opt/anaconda3/lib/python3.11/site-packages/anndata/_core/anndata.py:1823: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")
# AnnData object with n_obs × n_vars = 17125 × 36601
#     obs: 'sample'

# %%
# mitochondrial genes, "MT-" for human, "Mt-" for mouse
adata.var["mt"] = adata.var_names.str.startswith("MT-")
# ribosomal genes
adata.var["ribo"] = adata.var_names.str.startswith(("RPS", "RPL"))
# hemoglobin genes
adata.var["hb"] = adata.var_names.str.contains("^HB[^(P)]")

# %%
sc.pp.calculate_qc_metrics(adata, qc_vars=["mt", "ribo", "hb"], inplace=True, log1p=True)

# %%
sc.pl.violin(
    adata,
    ["n_genes_by_counts", "total_counts", "pct_counts_mt"],
    jitter=0.4,
    multi_panel=True,
)

# %%
sc.pl.scatter(adata, "total_counts", "n_genes_by_counts", color="pct_counts_mt")

# %%
sc.pp.filter_cells(adata, min_genes=100)
sc.pp.filter_genes(adata, min_cells=3)

# %%
sc.pp.scrublet(adata, batch_key="sample")

# %%
# Saving count data
adata.layers["counts"] = adata.X.copy()
# Normalizing to median total counts
sc.pp.normalize_total(adata)
# Logarithmize the data
sc.pp.log1p(adata)

# %%
sc.pp.highly_variable_genes(adata, n_top_genes=2000, batch_key="sample")
sc.pl.highly_variable_genes(adata)

# %%
sc.tl.pca(adata)
sc.pl.pca_variance_ratio(adata, n_pcs=50, log=True)

# %%
sc.pl.pca(
    adata,
    color=["sample", "sample", "pct_counts_mt", "pct_counts_mt"],
    dimensions=[(0, 1), (2, 3), (0, 1), (2, 3)],
    ncols=2,
    size=2,
)

# %%
sc.pp.neighbors(adata)
sc.tl.umap(adata)
sc.pl.umap(
    adata,
    color="sample",
    ncols=2,
    size=2,
)

# %%
# Using the igraph implementation and a fixed number of iterations can be significantly faster,
# especially for larger datasets
sc.tl.leiden(adata, flavor="igraph", n_iterations=2)
sc.pl.umap(adata, color="leiden", ncols=2, size=2)

# %%
sc.pl.umap(
    adata,
    color=["leiden", "predicted_doublet", "doublet_score"],
    # increase horizontal space between panels
    wspace=0.5,
    size=3,
)

# %%
sc.pl.umap(
    adata,
    color=["leiden", "log1p_total_counts", "pct_counts_mt", "log1p_n_genes_by_counts"],
    wspace=0.5,
    ncols=2,
)

# %%
for res in [0.02, 0.5, 2.0]:
    sc.tl.leiden(adata, key_added=f"leiden_res_{res:4.2f}", resolution=res, flavor="igraph")
sc.pl.umap(
    adata,
    color=["leiden_res_0.02", "leiden_res_0.50", "leiden_res_2.00"],
    legend_loc="on data",
)

# %%
marker_genes = {
    "CD14+ Mono": ["FCN1", "CD14"],
    "CD16+ Mono": ["TCF7L2", "FCGR3A", "LYN"],
    # Note: DMXL2 should be negative
    "cDC2": ["CST3", "COTL1", "LYZ", "DMXL2", "CLEC10A", "FCER1A"],
    "Erythroblast": ["MKI67", "HBA1", "HBB"],
    # Note HBM and GYPA are negative markers
    "Proerythroblast": ["CDK6", "SYNGR1", "HBM", "GYPA"],
    "NK": ["GNLY", "NKG7", "CD247", "FCER1G", "TYROBP", "KLRG1", "FCGR3A"],
    "ILC": ["ID2", "PLCG2", "GNLY", "SYNE1"],
    "Naive CD20+ B": ["MS4A1", "IL4R", "IGHD", "FCRL1", "IGHM"],
    # Note IGHD and IGHM are negative markers
    "B cells": [
        "MS4A1",
        "ITGB1",
        "COL4A4",
        "PRDM1",
        "IRF4",
        "PAX5",
        "BCL11A",
        "BLK",
        "IGHD",
        "IGHM",
    ],
    "Plasma cells": ["MZB1", "HSP90B1", "FNDC3B", "PRDM1", "IGKC", "JCHAIN"],
    # Note PAX5 is a negative marker
    "Plasmablast": ["XBP1", "PRDM1", "PAX5"],
    "CD4+ T": ["CD4", "IL7R", "TRBC2"],
    "CD8+ T": ["CD8A", "CD8B", "GZMK", "GZMA", "CCL5", "GZMB", "GZMH", "GZMA"],
    "T naive": ["LEF1", "CCR7", "TCF7"],
    "pDC": ["GZMB", "IL3RA", "COBLL1", "TCF4"],
}
sc.pl.dotplot(adata, marker_genes, groupby="leiden_res_0.02", standard_scale="var")

# %%
adata.obs["cell_type_lvl1"] = adata.obs["leiden_res_0.02"].map(
    {
        "0": "Lymphocytes",
        "1": "Monocytes",
        "2": "Erythroid",
        "3": "B Cells",
    }
)
sc.pl.dotplot(adata, marker_genes, groupby="leiden_res_2.00", standard_scale="var")

# %%
# Obtain cluster-specific differentially expressed genes
sc.tl.rank_genes_groups(adata, groupby="leiden_res_0.50", method="wilcoxon")

# %%
sc.pl.rank_genes_groups_dotplot(adata, groupby="leiden_res_0.50", standard_scale="var", n_genes=5)
# Out:
# WARNING: dendrogram data not found (using key=dendrogram_leiden_res_0.50). Running `sc.tl.dendrogram` with default parameters. For fine tuning it is recommended to run `sc.tl.dendrogram` independently.

# %%
dc_cluster_genes = sc.get.rank_genes_groups_df(adata, group="7").head(5)["names"]
sc.pl.umap(
    adata,
    color=[*dc_cluster_genes, "leiden_res_0.50"],
    legend_loc="on data",
    frameon=False,
    ncols=3,
)
